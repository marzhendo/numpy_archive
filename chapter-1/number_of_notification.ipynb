# %%
import numpy as np

# %%
notifications = np.array([133, 624, 686, 391, 320, 296, 358])
total_notifications = np.sum(notifications)
print(f'Total notifications in a week: {total_notifications}')
# Out:
# Total notifications in a week: 2808
