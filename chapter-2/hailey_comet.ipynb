# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Hailey's Comet data
comet_years = np.arange(start = 1986, stop = 3000, step = 75)
print("Tahun-tahun kemunculan Hailey's Comet:", comet_years)
# Cek jumlah elemen dalam comet_years
print("Jumlah kemunculan Hailey's Comet:", comet_years.shape[0])
# Bentuk ulang array menjadi 2 x 7
comet_reshaped = comet_years.reshape(2, 7)
print("Comet years reshaped:\n", comet_reshaped)
